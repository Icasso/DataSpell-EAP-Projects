# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
comments_df = pd.read_pickle("comments_with_textblob_df.pkl")
# comments_df = comments_df[0:1000]

# %%
comments_df
# Out:
#                                                       body created_utc Symbol  \
# 4482265                   Not even close to enough rockets  2021-01-01
# 2298808                             no product, no revenue  2021-01-01
# 4481342                  Green apple Jack Daniels and coke  2021-01-01
# 4482266                                         I did this  2021-01-01
# 4481339                                       Not his own.  2021-01-01
# ...                                                    ...         ...    ...
# 6743926      FAUCI is just mad that a bull fuked his wife.  2021-11-28
# 6743925  He said in his opinion vaccines where effectiv...  2021-11-28
# 6743923  The boyfriend of my wife and his stepmother ar...  2021-11-28
# 6743921  This sounds eerily similar to my relationship ...  2021-11-28
# 6743428                         Yo College!!! FUK U!!!!! 🤓  2021-11-28
#
#          TextBlob_Polarity  TextBlob_Subjectivity
# 4482265              0.000               0.500000
# ...

# %%
body_list = comments_df.body.tolist()

# %%
vader = SentimentIntensityAnalyzer()

# %%
default_vader = []

# %%
# %%time
for s in body_list:
    default_vader.append(vader.polarity_scores(s))
# Out:
# CPU times: user 25min 31s, sys: 9.73 s, total: 25min 41s
# Wall time: 25min 56s

# %%
default_vader
# Out:
# [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.688, 'neu': 0.312, 'pos': 0.0, 'compound': -0.5267},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.3744},
#  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.6858},
#  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.3612},
#  {'neg': 0.12, 'neu': 0.785, 'pos': 0.094, 'compound': -0.128},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.423, 'neu': 0.577, 'pos': 0.0, 'compound': -0.296},
#  {'neg': 0.054, 'neu': 0.7, 'pos': 0.245, 'compound': 0.7096},
#  {'neg': 0.12, 'neu': 0.787, 'pos': 0.093, 'compound': -0.2006},
#  {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.4588},
# ...

# %%
len(default_vader)
# Out:
# 17681183

# %%
neg = []
neu = []
pos = []
compound = []
for i in default_vader:
    neg.append(i['neg'])
    neu.append(i['neu'])
    pos.append(i['pos'])
    compound.append(i['compound'])

# %%
comments_df["Default_Vader_Negative"] = neg
comments_df["Default_Vader_Neutral"] = neu
comments_df["Default_Vader_Positive"] = pos
comments_df["Default_Vader_Compound"] = compound
comments_df
# Out:
#                                                       body created_utc Symbol  \
# 4482265                   Not even close to enough rockets  2021-01-01
# 2298808                             no product, no revenue  2021-01-01
# 4481342                  Green apple Jack Daniels and coke  2021-01-01
# 4482266                                         I did this  2021-01-01
# 4481339                                       Not his own.  2021-01-01
# ...                                                    ...         ...    ...
# 6743926      FAUCI is just mad that a bull fuked his wife.  2021-11-28
# 6743925  He said in his opinion vaccines where effectiv...  2021-11-28
# 6743923  The boyfriend of my wife and his stepmother ar...  2021-11-28
# 6743921  This sounds eerily similar to my relationship ...  2021-11-28
# 6743428                         Yo College!!! FUK U!!!!! 🤓  2021-11-28
#
#          TextBlob_Polarity  TextBlob_Subjectivity  Default_Vader_Negative  \
# ...

# %%
comments_df.to_pickle('comments_with_textblob_dvader_df.pkl')

# %%
comments_df
# Out:
#                                                       body created_utc Symbol  \
# 4482265                   Not even close to enough rockets  2021-01-01
# 2298808                             no product, no revenue  2021-01-01
# 4481342                  Green apple Jack Daniels and coke  2021-01-01
# 4482266                                         I did this  2021-01-01
# 4481339                                       Not his own.  2021-01-01
# ...                                                    ...         ...    ...
# 6743926      FAUCI is just mad that a bull fuked his wife.  2021-11-28
# 6743925  He said in his opinion vaccines where effectiv...  2021-11-28
# 6743923  The boyfriend of my wife and his stepmother ar...  2021-11-28
# 6743921  This sounds eerily similar to my relationship ...  2021-11-28
# 6743428                         Yo College!!! FUK U!!!!! 🤓  2021-11-28
#
#          TextBlob_Polarity  TextBlob_Subjectivity  Default_Vader_Negative  \
# ...
